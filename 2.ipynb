# %%
import pandas as pd
import openpyxl

# %%
#df=pd.read_csv(r"C:\Users\Admin\OneDrive\Documents\jupyter notebook\bus_data.csv")
#df

#df = pd.read_excel("C:/Users/Admin/OneDrive/Documents/jupyter notebook/bus_data.xlsx")
#df

df = pd.read_csv(r"C:\Users\Admin\OneDrive\Documents\jupyter notebook\bus_data.txt", delimiter='\t',header=1) #header=1 remove row one
df
# Out:
#    College        Student name  Univ Reg No.  \
# 0    KSRCT            AARTHI K   73772126101
# 1    KSRCT  ABINAV CHANDAR R S   73772126102
# 2    KSRCT       ABISHECKRAJ M   73772126103
# 3    KSRCT          AKSHATHA K   73772126104
# 4    KSRCT           ARAVIND S   73772126105
# ..     ...                 ...           ...
# 59   KSRCT       YOGESHWARAN K   73772126160
# 60   KSRCT          YUVASREE M   73772126161
# 61   KSRCT         PRAVEEN R K   73772126401
# 62   KSRCT             VIJAY T   73772126402
# 63   KSRCT            VISHWA S   73772126403
#
#                                              Roll No. Present Address1  \
# 0   D/O S KUMAR, 2/230, AMMAIYANDI WEST, AMMAIYAND...        THANJAVUR
# 1   S/O CR RANJITH RAMKUMAR, 12/314 NETHAJI NAGAR,...            ERODE
# 2   S/O P MAHALINGAM, 167,PACHAGOUNDANUR,  SELAVAD...            SALEM
# 3   D/O R KARTHIKEYAN, 8/47, KUMARAN NAGAR, RS ROA...            ERODE
# ...

# %%
df.head(2)
# Out:
#   College        Student name  Univ Reg No.  \
# 0   KSRCT            AARTHI K   73772126101
# 1   KSRCT  ABINAV CHANDAR R S   73772126102
#
#                                             Roll No. Present Address1  \
# 0  D/O S KUMAR, 2/230, AMMAIYANDI WEST, AMMAIYAND...        THANJAVUR
# 1  S/O CR RANJITH RAMKUMAR, 12/314 NETHAJI NAGAR,...            ERODE
#
#          City  State  Country  \
# 0  TAMIL NADU  India   614623
# 1   TAMILNADU  India   638004
#
#                                                  PIN Permanent Address 1  \
# 0                             2/230, AMMAIYANDI WEST                 NaN
# 1  12/314 NETHAJI NAGAR, MANICKAMPALAYAM ROAD, PE...                 NaN
#
#   Day-Scholar through Out Bus / Own Vechicle / by walk Hosteller  \
# 0                                          Hosteller         NaN
# 1                                          Hosteller         NaN
#
#   Day-Scholar through College Bus Buss Stop Name Buss Number Buss End  Stop
# ...

# %%
df.tail()
# Out:
#    College   Student name  Univ Reg No.  \
# 59   KSRCT  YOGESHWARAN K   73772126160
# 60   KSRCT     YUVASREE M   73772126161
# 61   KSRCT    PRAVEEN R K   73772126401
# 62   KSRCT        VIJAY T   73772126402
# 63   KSRCT       VISHWA S   73772126403
#
#                                              Roll No. Present Address1  \
# 59  S/O N KUMAR, MAHALINGA MOORTI NAGAR, AVUDAIYAR...      PUDUKKOTTAI
# 60  D/O S MADHESWARAN, 1-8/17,PERIYAR NAGAR, KARUM...         NAMAKKAL
# 61  S/O R KANNAN, 75/104, MARRIAMMAN KOVIL STREET,...            SALEM
# 62  S/O P TAMILSELVAN, 34, PAPPATHI AMMAN KOVIL ST...         NAMAKKAL
# 63  S/O R SIVA KUMAR, 1/264, SENGUNDHAR NAGAR, NEI...         NAMAKKAL
#
#           City  State  Country  \
# 59  TAMIL NADU  India   614618
# 60   TAMILNADU  India   638183
# 61  TAMIL NADU  India   636007
# 62  TAMIL NADU  India   638181
# 63  TAMIL NADU  India   637209
#
#                                                   PIN Permanent Address 1  \
# ...

# %%
df.columns
# Out:
# Index(['College', 'Student name', 'Univ Reg No.', 'Roll No.',
#        'Present Address1', 'City', 'State', 'Country', 'PIN',
#        'Permanent Address 1',
#        'Day-Scholar through Out Bus / Own Vechicle / by walk', 'Hosteller',
#        'Day-Scholar through College Bus', 'Buss Stop Name', 'Buss Number',
#        'Buss End  Stop '],
#       dtype='object')

# %%
#df["College"]
#df["College"][0:5]
#df.College
df.College[0:5]
# Out:
# 0    KSRCT
# 1    KSRCT
# 2    KSRCT
# 3    KSRCT
# 4    KSRCT
# Name: College, dtype: object

# %%
df.iloc[0:29] #[0:n-1]
# Out:
#    College        Student name  Univ Reg No.  \
# 0    KSRCT            AARTHI K   73772126101
# 1    KSRCT  ABINAV CHANDAR R S   73772126102
# 2    KSRCT       ABISHECKRAJ M   73772126103
# 3    KSRCT          AKSHATHA K   73772126104
# 4    KSRCT           ARAVIND S   73772126105
# 5    KSRCT         ARCHANA A M   73772126106
# 6    KSRCT   BHARANIDHARAN M P   73772126107
# 7    KSRCT       BHARANIRAJA R   73772126108
# 8    KSRCT      BHAVATHARANY E   73772126109
# 9    KSRCT        CHITTESH S P   73772126110
# 10   KSRCT    DEEPAK KRISHNA S   73772126111
# 11   KSRCT      DEVADARSHINI D   73772126112
# 12   KSRCT           DEVARAJ S   73772126113
# 13   KSRCT           DHANUSH S   73772126114
# 14   KSRCT         DIBAKARAN K   73772126115
# 15   KSRCT          GAYATHRI S   73772126116
# 16   KSRCT            GOBIKA B   73772126117
# 17   KSRCT         GOKULNATH V   73772126118
# 18   KSRCT     GOWTHAMBALAGI M   73772126119
# 19   KSRCT       GOWTHAMAN R L   73772126120
# ...

# %%
df.iloc[27,1]
# Out:
# 'MATHIVEENDHAN P'

# %%
df.iloc[27]
# Out:
# College                                                                                             KSRCT
# Student name                                                                              MATHIVEENDHAN P
# Univ Reg No.                                                                                  73772126128
# Roll No.                                                S/O T PALANISAMY, 134,ERODE ROAD, 2ND STREET, ...
# Present Address1                                                                                 TIRUPPUR
# City                                                                                           TAMIL NADU
# State                                                                                               India
# Country                                                                                            638105
# PIN                                                                    134,ERODE ROAD, 2ND STREET, MUTHUR
# ...

# %%
df.iloc[0:29,1]
# Out:
# 0               AARTHI K
# 1     ABINAV CHANDAR R S
# 2          ABISHECKRAJ M
# 3             AKSHATHA K
# 4              ARAVIND S
# 5            ARCHANA A M
# 6      BHARANIDHARAN M P
# 7          BHARANIRAJA R
# 8         BHAVATHARANY E
# 9           CHITTESH S P
# 10      DEEPAK KRISHNA S
# 11        DEVADARSHINI D
# 12             DEVARAJ S
# 13             DHANUSH S
# 14           DIBAKARAN K
# 15            GAYATHRI S
# 16              GOBIKA B
# 17           GOKULNATH V
# 18       GOWTHAMBALAGI M
# 19         GOWTHAMAN R L
# 20                GUNA A
# 21        JASIM AHAMED J
# 22            KAMALESH M
# 23         KIRUBASHINI V
# 24         LOGESHWARAN B
# 25     MANONAVANEETHAN M
# 26          MATHINESAN P
# 27       MATHIVEENDHAN P
# 28           MEIKANDAN R
# Name: Student name, dtype: object

# %%
#manually insert data

data={"name":['tamil','shiva','madara','itachi','luffy','zoro','goku','ichigo']}
dataf=pd.DataFrame(data)
dataf
# Out:
#      name
# 0   tamil
# 1   shiva
# 2  madara
# 3  itachi
# 4   luffy
# 5    zoro
# 6    goku
# 7  ichigo

# %%
df.columns
# Out:
# Index(['College', 'Student name', 'Univ Reg No.', 'Roll No.',
#        'Present Address1', 'City', 'State', 'Country', 'PIN',
#        'Permanent Address 1',
#        'Day-Scholar through Out Bus / Own Vechicle / by walk', 'Hosteller',
#        'Day-Scholar through College Bus', 'Buss Stop Name', 'Buss Number',
#        'Buss End  Stop '],
#       dtype='object')

# %%
df.iloc[27]
# Out:
# College                                                                                             KSRCT
# Student name                                                                              MATHIVEENDHAN P
# Univ Reg No.                                                                                  73772126128
# Roll No.                                                S/O T PALANISAMY, 134,ERODE ROAD, 2ND STREET, ...
# Present Address1                                                                                 TIRUPPUR
# City                                                                                           TAMIL NADU
# State                                                                                               India
# Country                                                                                            638105
# PIN                                                                    134,ERODE ROAD, 2ND STREET, MUTHUR
# ...

# %%
#df.replace("KSRCT","ksr") change valus in tha dataframe
df.rename(columns={"Student name":"Student_name",'Univ_Reg_No.':'Roll_No','Roll_No.':'Address'},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 16 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   College                                               64 non-null     object
#  1   Student_name                                          64 non-null     object
#  2   Univ Reg No.                                          64 non-null     int64
#  3   Roll No.                                              64 non-null     object
#  4   Present Address1                                      64 non-null     object
#  5   City                                                  64 non-null     object
#  6   State                                                 64 non-null     object
#  7   Country                                               64 non-null     int64
# ...

# %%
df.columns = df.columns.str.replace(' ','_')
df.columns=df.columns.str.replace("Buss","Bus")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 16 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   College                                               64 non-null     object
#  1   Student_name                                          64 non-null     object
#  2   Univ_Reg_No.                                          64 non-null     int64
#  3   Roll_No.                                              64 non-null     object
#  4   Present_Address1                                      64 non-null     object
#  5   City                                                  64 non-null     object
#  6   State                                                 64 non-null     object
#  7   Country                                               64 non-null     int64
# ...

# %%
df.loc[df["Day-Scholar_through_Out_Bus_/_Own_Vechicle_/_by_walk"] == "Hosteller"]
# Out:
#    College          Student_name  Univ_Reg_No.  \
# 0    KSRCT              AARTHI K   73772126101
# 1    KSRCT    ABINAV CHANDAR R S   73772126102
# 2    KSRCT         ABISHECKRAJ M   73772126103
# 3    KSRCT            AKSHATHA K   73772126104
# 8    KSRCT        BHAVATHARANY E   73772126109
# 14   KSRCT           DIBAKARAN K   73772126115
# 17   KSRCT           GOKULNATH V   73772126118
# 18   KSRCT       GOWTHAMBALAGI M   73772126119
# 21   KSRCT        JASIM AHAMED J   73772126122
# 31   KSRCT            MURUGESH M   73772126132
# 32   KSRCT          MUTHUPANDI B   73772126133
# 35   KSRCT             NAVITHA S   73772126136
# 39   KSRCT           RADHIDEVI K   73772126140
# 44   KSRCT       RUTHRAVARSHAN S   73772126145
# 55   KSRCT  VISHNU KARTHIKEYAN K   73772126156
#
#                                              Roll_No. Present_Address1  \
# 0   D/O S KUMAR, 2/230, AMMAIYANDI WEST, AMMAIYAND...        THANJAVUR
# ...

# %%
df.describe()
# Out:
#        Univ_Reg_No.        Country
# count  6.400000e+01      64.000000
# mean   7.377213e+10  633835.843750
# std    6.027811e+01    8946.987001
# min    7.377213e+10  606003.000000
# 25%    7.377213e+10  636006.250000
# 50%    7.377213e+10  637155.000000
# 75%    7.377213e+10  638069.000000
# max    7.377213e+10  641666.000000

# %%
df.sort_values("Student_name",ascending=True)
#df.sort_values("Student_name",ascending=False)
#mutiple columns use df.sort_values(['Student_name','Univ_Reg_no'],Ascending=True)
# Out:
#    College        Student_name  Univ_Reg_No.  \
# 0    KSRCT            AARTHI K   73772126101
# 1    KSRCT  ABINAV CHANDAR R S   73772126102
# 2    KSRCT       ABISHECKRAJ M   73772126103
# 3    KSRCT          AKSHATHA K   73772126104
# 4    KSRCT           ARAVIND S   73772126105
# ..     ...                 ...           ...
# 63   KSRCT            VISHWA S   73772126403
# 57   KSRCT         VISHWARAJ S   73772126158
# 58   KSRCT         YASHWIN G M   73772126159
# 59   KSRCT       YOGESHWARAN K   73772126160
# 60   KSRCT          YUVASREE M   73772126161
#
#                                              Roll_No. Present_Address1  \
# 0   D/O S KUMAR, 2/230, AMMAIYANDI WEST, AMMAIYAND...        THANJAVUR
# 1   S/O CR RANJITH RAMKUMAR, 12/314 NETHAJI NAGAR,...            ERODE
# 2   S/O P MAHALINGAM, 167,PACHAGOUNDANUR,  SELAVAD...            SALEM
# 3   D/O R KARTHIKEYAN, 8/47, KUMARAN NAGAR, RS ROA...            ERODE
# ...

# %%
df
# Out:
#    College        Student_name  Univ_Reg_No.  \
# 0    KSRCT            AARTHI K   73772126101
# 1    KSRCT  ABINAV CHANDAR R S   73772126102
# 2    KSRCT       ABISHECKRAJ M   73772126103
# 3    KSRCT          AKSHATHA K   73772126104
# 4    KSRCT           ARAVIND S   73772126105
# ..     ...                 ...           ...
# 59   KSRCT       YOGESHWARAN K   73772126160
# 60   KSRCT          YUVASREE M   73772126161
# 61   KSRCT         PRAVEEN R K   73772126401
# 62   KSRCT             VIJAY T   73772126402
# 63   KSRCT            VISHWA S   73772126403
#
#                                              Roll_No. Present_Address1  \
# 0   D/O S KUMAR, 2/230, AMMAIYANDI WEST, AMMAIYAND...        THANJAVUR
# 1   S/O CR RANJITH RAMKUMAR, 12/314 NETHAJI NAGAR,...            ERODE
# 2   S/O P MAHALINGAM, 167,PACHAGOUNDANUR,  SELAVAD...            SALEM
# 3   D/O R KARTHIKEYAN, 8/47, KUMARAN NAGAR, RS ROA...            ERODE
# ...

# %%
#df.to_csv("result.csv")
df.to_excel('result.xlsx')

# %%
df.loc[(df["Day-Scholar_through_Out_Bus_/_Own_Vechicle_/_by_walk"] == "Hosteller") & (df["Present_Address1"] =="ERODE")]
# Out:
#    College          Student_name  Univ_Reg_No.  \
# 1    KSRCT    ABINAV CHANDAR R S   73772126102
# 3    KSRCT            AKSHATHA K   73772126104
# 44   KSRCT       RUTHRAVARSHAN S   73772126145
# 55   KSRCT  VISHNU KARTHIKEYAN K   73772126156
#
#                                              Roll_No. Present_Address1  \
# 1   S/O CR RANJITH RAMKUMAR, 12/314 NETHAJI NAGAR,...            ERODE
# 3   D/O R KARTHIKEYAN, 8/47, KUMARAN NAGAR, RS ROA...            ERODE
# 44  S/O P SELVAN, 4/187 , KOTTAIPUDHUR , PERIYAKAL...            ERODE
# 55  S/O K G KUPPUSAMY, 4/99, KEELARIPALAYAM, SEENA...            ERODE
#
#           City  State Permanent_Address_1  \
# 1    TAMILNADU  India                 NaN
# 3   TAMIl NADU  India                 NaN
# 44  TAMIL NADU  India                 NaN
# 55   TAMILNADU  India                 NaN
#
#    Day-Scholar_through_Out_Bus_/_Own_Vechicle_/_by_walk Hosteller  \
# 1                                           Hosteller         NaN
# ...

# %%
df.loc[(df["Day-Scholar_through_Out_Bus_/_Own_Vechicle_/_by_walk"] == "Hosteller") | (df["Present_Address1"] =="ERODE")]
# Out:
#    College          Student_name  Univ_Reg_No.  \
# 0    KSRCT              AARTHI K   73772126101
# 1    KSRCT    ABINAV CHANDAR R S   73772126102
# 2    KSRCT         ABISHECKRAJ M   73772126103
# 3    KSRCT            AKSHATHA K   73772126104
# 5    KSRCT           ARCHANA A M   73772126106
# 8    KSRCT        BHAVATHARANY E   73772126109
# 14   KSRCT           DIBAKARAN K   73772126115
# 17   KSRCT           GOKULNATH V   73772126118
# 18   KSRCT       GOWTHAMBALAGI M   73772126119
# 21   KSRCT        JASIM AHAMED J   73772126122
# 31   KSRCT            MURUGESH M   73772126132
# 32   KSRCT          MUTHUPANDI B   73772126133
# 35   KSRCT             NAVITHA S   73772126136
# 36   KSRCT            PRASANTH R   73772126137
# 37   KSRCT       PRAVEEN KUMAR S   73772126138
# 39   KSRCT           RADHIDEVI K   73772126140
# 43   KSRCT         RITHICAGASH J   73772126144
# 44   KSRCT       RUTHRAVARSHAN S   73772126145
# 45   KSRCT         SABAREESH M B   73772126146
# ...

# %%
#df.loc[df['Present_Address1'].str.contains('ERODE')]
df.loc[~df['Present_Address1'].str.contains('ERODE')] #not operator used
# Out:
#    College       Student_name  Univ_Reg_No.  \
# 0    KSRCT           AARTHI K   73772126101
# 2    KSRCT      ABISHECKRAJ M   73772126103
# 4    KSRCT          ARAVIND S   73772126105
# 6    KSRCT  BHARANIDHARAN M P   73772126107
# 7    KSRCT      BHARANIRAJA R   73772126108
# 8    KSRCT     BHAVATHARANY E   73772126109
# 9    KSRCT       CHITTESH S P   73772126110
# 10   KSRCT   DEEPAK KRISHNA S   73772126111
# 11   KSRCT     DEVADARSHINI D   73772126112
# 12   KSRCT          DEVARAJ S   73772126113
# 13   KSRCT          DHANUSH S   73772126114
# 14   KSRCT        DIBAKARAN K   73772126115
# 15   KSRCT         GAYATHRI S   73772126116
# 16   KSRCT           GOBIKA B   73772126117
# 17   KSRCT        GOKULNATH V   73772126118
# 18   KSRCT    GOWTHAMBALAGI M   73772126119
# 19   KSRCT      GOWTHAMAN R L   73772126120
# 20   KSRCT             GUNA A   73772126121
# 21   KSRCT     JASIM AHAMED J   73772126122
# 22   KSRCT         KAMALESH M   73772126123
# ...
