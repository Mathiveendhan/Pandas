# %%
import pandas as pd

# %%
#df=pd.read_csv(r"C:\Users\Admin\OneDrive\Documents\Dataset\samsung_mobile_new_data.csv")
#df=pd.read_csv("C:/Users/Admin/OneDrive/Documents/Dataset/samsung_mobile_new_data.csv")
df=pd.read_csv(r"C:\\Users\\Admin\\OneDrive\\Documents\\Dataset\\samsung_mobile_new_data.csv")

# %%
df
# Out:
#                                                 name  ratings    price  \
# 0         SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3   ₹9,499
# 1        SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  ₹10,499
# 2        SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3  ₹10,499
# 3        SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      4.3  ₹10,499
# 4          SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3  ₹15,499
# ..                                               ...      ...      ...
# 571  SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)      4.3  ₹16,199
# 572            SAMSUNG Galaxy J4 Plus (Black, 32 GB)      4.4   ₹9,000
# 573   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)      4.2  ₹34,999
# 574                SAMSUNG Galaxy M01s (Gray, 32 GB)      NaN  ₹10,999
# 575           SAMSUNG Galaxy S22 (Pink Gold, 128 GB)      NaN  ₹85,999
#
#                                                 imgURL  \
# 0    https://rukminim2.flixcart.com/image/312/312/x...
# ...

# %%
df.head(3)
# Out:
#                                           name  ratings    price  \
# 0   SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3   ₹9,499
# 1  SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  ₹10,499
# 2  SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3  ₹10,499
#
#                                               imgURL  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...
# 1  https://rukminim2.flixcart.com/image/312/312/x...
# 2  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                          storage_ram  \
# 0  Internal Storage64 GBRAM4 GBExpandable Storage...
# 1  Internal Storage128 GBRAM4 GBExpandable Storag...
# 2  Internal Storage128 GBRAM4 GBExpandable Storag...
#
#                                         os_processor  \
# 0  Operating SystemAndroid 12Processor TypeExynos...
# 1  Operating SystemAndroid 12Processor TypeExynos...
# 2  Operating SystemAndroid 12Processor TypeExynos...
#
# ...

# %%
df.tail(5)
# Out:
#                                                 name  ratings    price  \
# 571  SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)      4.3  ₹16,199
# 572            SAMSUNG Galaxy J4 Plus (Black, 32 GB)      4.4   ₹9,000
# 573   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)      4.2  ₹34,999
# 574                SAMSUNG Galaxy M01s (Gray, 32 GB)      NaN  ₹10,999
# 575           SAMSUNG Galaxy S22 (Pink Gold, 128 GB)      NaN  ₹85,999
#
#                                                 imgURL  \
# 571  https://rukminim2.flixcart.com/image/312/312/k...
# 572  https://rukminim2.flixcart.com/image/312/312/j...
# 573  https://rukminim2.flixcart.com/image/312/312/k...
# 574  https://rukminim2.flixcart.com/image/312/312/k...
# 575  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram  \
# 571  Internal Storage64 GBRAM4 GBSupported Memory C...
# 572  Internal Storage32 GBRAM2 GBExpandable Storage...
# ...

# %%
df.shape
# Out:
# (576, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          576 non-null    object
#  1   ratings       553 non-null    float64
#  2   price         576 non-null    object
#  3   imgURL        576 non-null    object
#  4   storage_ram   570 non-null    object
#  5   os_processor  555 non-null    object
#  6   camera        562 non-null    object
#  7   display       573 non-null    object
#  8   network       565 non-null    object
#  9   battery       573 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 45.1+ KB

# %%
df.columns
# Out:
# Index(['name', 'ratings', 'price', 'imgURL', 'storage_ram', 'os_processor',
#        'camera', 'display', 'network', 'battery'],
#       dtype='object')

# %%
#####accessing dataframe using LIST######

# %%
df.iloc[0]
# Out:
# name                   SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)
# ratings                                                       4.3
# price                                                      ₹9,499
# imgURL          https://rukminim2.flixcart.com/image/312/312/x...
# storage_ram     Internal Storage64 GBRAM4 GBExpandable Storage...
# os_processor    Operating SystemAndroid 12Processor TypeExynos...
# camera          Primary Camera AvailableYesPrimary Camera50MP ...
# display         Display Size16.76 cm (6.6 inch)Resolution2408 ...
# network         Network Type4G, 3G, 2GSupported Networks4G LTE...
# battery                    Battery Capacity6000 mAhDual BatteryNo
# Name: 0, dtype: object

# %%
df.iloc[[0,2]]
# Out:
#                                           name  ratings    price  \
# 0   SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3   ₹9,499
# 2  SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3  ₹10,499
#
#                                               imgURL  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...
# 2  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                          storage_ram  \
# 0  Internal Storage64 GBRAM4 GBExpandable Storage...
# 2  Internal Storage128 GBRAM4 GBExpandable Storag...
#
#                                         os_processor  \
# 0  Operating SystemAndroid 12Processor TypeExynos...
# 2  Operating SystemAndroid 12Processor TypeExynos...
#
#                                               camera  \
# 0  Primary Camera AvailableYesPrimary Camera50MP ...
# 2  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                              display  \
# 0  Display Size16.76 cm (6.6 inch)Resolution2408 ...
# ...

# %%
df.iloc[[0,3],2]
# Out:
# 0     ₹9,499
# 3    ₹10,499
# Name: price, dtype: object

# %%
df.loc[0]
# Out:
# name                   SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)
# ratings                                                       4.3
# price                                                      ₹9,499
# imgURL          https://rukminim2.flixcart.com/image/312/312/x...
# storage_ram     Internal Storage64 GBRAM4 GBExpandable Storage...
# os_processor    Operating SystemAndroid 12Processor TypeExynos...
# camera          Primary Camera AvailableYesPrimary Camera50MP ...
# display         Display Size16.76 cm (6.6 inch)Resolution2408 ...
# network         Network Type4G, 3G, 2GSupported Networks4G LTE...
# battery                    Battery Capacity6000 mAhDual BatteryNo
# Name: 0, dtype: object

# %%
df.loc[[0,2]]
# Out:
#                                           name  ratings    price  \
# 0   SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3   ₹9,499
# 2  SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3  ₹10,499
#
#                                               imgURL  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...
# 2  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                          storage_ram  \
# 0  Internal Storage64 GBRAM4 GBExpandable Storage...
# 2  Internal Storage128 GBRAM4 GBExpandable Storag...
#
#                                         os_processor  \
# 0  Operating SystemAndroid 12Processor TypeExynos...
# 2  Operating SystemAndroid 12Processor TypeExynos...
#
#                                               camera  \
# 0  Primary Camera AvailableYesPrimary Camera50MP ...
# 2  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                              display  \
# 0  Display Size16.76 cm (6.6 inch)Resolution2408 ...
# ...

# %%
df.loc[[0,2],'os_processor']
# Out:
# 0    Operating SystemAndroid 12Processor TypeExynos...
# 2    Operating SystemAndroid 12Processor TypeExynos...
# Name: os_processor, dtype: object

# %%
df.loc[[0,2],['os_processor','storage_ram']]
# Out:
#                                         os_processor  \
# 0  Operating SystemAndroid 12Processor TypeExynos...
# 2  Operating SystemAndroid 12Processor TypeExynos...
#
#                                          storage_ram
# 0  Internal Storage64 GBRAM4 GBExpandable Storage...
# 2  Internal Storage128 GBRAM4 GBExpandable Storag...

# %%
df['storage_ram']
# Out:
# 0      Internal Storage64 GBRAM4 GBExpandable Storage...
# 1      Internal Storage128 GBRAM4 GBExpandable Storag...
# 2      Internal Storage128 GBRAM4 GBExpandable Storag...
# 3      Internal Storage128 GBRAM4 GBExpandable Storag...
# 4      Internal Storage128 GBRAM6 GBTotal Memory128 G...
#                              ...
# 571    Internal Storage64 GBRAM4 GBSupported Memory C...
# 572    Internal Storage32 GBRAM2 GBExpandable Storage...
# 573    Internal Storage128 GBRAM8 GBExpandable Storag...
# 574    Internal Storage32 GBRAM3 GBExpandable Storage...
# 575    Internal Storage128 GBRAM8 GBMemory Card Slot ...
# Name: storage_ram, Length: 576, dtype: object

# %%
df["name"].value_counts()    ####count of the item
# Out:
# name
# OPPO Reno10 5G (Silvery Grey, 256 GB)            8
# SAMSUNG Metro 313                                7
# OPPO Reno10 5G (Ice Blue, 256 GB)                6
# SAMSUNG Guru Music 2                             6
# SAMSUNG Galaxy M32 5G (Sky Blue, 128 GB)         4
#                                                 ..
# SAMSUNG Galaxy A52s 5G (Awesome Mint, 128 GB)    1
# SAMSUNG Galaxy A53 (Awesome Blue, 256 GB)        1
# SAMSUNG Galaxy Z Flip4 5G (Graphite, 128 GB)     1
# SAMSUNG Galaxy A73 5G (Awesome White, 128 GB)    1
# SAMSUNG Galaxy S22 (Pink Gold, 128 GB)           1
# Name: count, Length: 414, dtype: int64

# %%
### accessing specific data in that corresponding rows ###

# %%
df.loc[[2,88,94],"battery"]
# Out:
# 2     Battery Capacity6000 mAhDual BatteryNo
# 88                  Battery Capacity6000 mAh
# 94    Battery Capacity5000 mAhDual BatteryNo
# Name: battery, dtype: object

# %%
### Slicing####

# %%
df.loc[0:35]
# Out:
#                                                name  ratings    price  \
# 0        SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3   ₹9,499
# 1       SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  ₹10,499
# 2       SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3  ₹10,499
# 3       SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      4.3  ₹10,499
# 4         SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3  ₹15,499
# 5      SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)      4.3  ₹15,499
# 6           SAMSUNG Galaxy F04 (Jade Purple, 64 GB)      4.2   ₹6,999
# 7            SAMSUNG Galaxy F04 (Opal Green, 64 GB)      4.2   ₹6,999
# 8        SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)      4.2  ₹13,990
# 9      SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)      4.3  ₹15,499
# 10        SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)      4.2  ₹13,990
# 11            SAMSUNG Galaxy M04 (Dark Blue, 64 GB)      4.1   ₹8,093
# ...

# %%
df.loc[1:35,'imgURL']
# Out:
# 1     https://rukminim2.flixcart.com/image/312/312/x...
# 2     https://rukminim2.flixcart.com/image/312/312/x...
# 3     https://rukminim2.flixcart.com/image/312/312/x...
# 4     https://rukminim2.flixcart.com/image/312/312/x...
# 5     https://rukminim2.flixcart.com/image/312/312/x...
# 6     https://rukminim2.flixcart.com/image/312/312/x...
# 7     https://rukminim2.flixcart.com/image/312/312/x...
# 8     https://rukminim2.flixcart.com/image/312/312/x...
# 9     https://rukminim2.flixcart.com/image/312/312/x...
# 10    https://rukminim2.flixcart.com/image/312/312/x...
# 11    https://rukminim2.flixcart.com/image/312/312/x...
# 12    https://rukminim2.flixcart.com/image/312/312/x...
# 13    https://rukminim2.flixcart.com/image/312/312/x...
# 14    https://rukminim2.flixcart.com/image/312/312/x...
# 15    https://rukminim2.flixcart.com/image/312/312/x...
# 16    https://rukminim2.flixcart.com/image/312/312/k...
# 17    https://rukminim2.flixcart.com/image/312/312/x...
# ...

# %%
df.loc[1:17,'name']
# Out:
# 1      SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)
# 2      SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)
# 3      SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)
# 4        SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)
# 5     SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)
# 6          SAMSUNG Galaxy F04 (Jade Purple, 64 GB)
# 7           SAMSUNG Galaxy F04 (Opal Green, 64 GB)
# 8       SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)
# 9     SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)
# 10       SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)
# 11           SAMSUNG Galaxy M04 (Dark Blue, 64 GB)
# 12      SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)
# 13         SAMSUNG Galaxy M04 (Light Green, 64 GB)
# 14      SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)
# 15       SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)
# 16                            SAMSUNG Guru Music 2
# 17      SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)
# Name: name, dtype: object

# %%
df.columns
# Out:
# Index(['name', 'ratings', 'price', 'imgURL', 'storage_ram', 'os_processor',
#        'camera', 'display', 'network', 'battery'],
#       dtype='object')

# %%
df.loc[1:17 , 'name':'price']
# Out:
#                                             name  ratings    price
# 1    SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  ₹10,499
# 2    SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3  ₹10,499
# 3    SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      4.3  ₹10,499
# 4      SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3  ₹15,499
# 5   SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)      4.3  ₹15,499
# 6        SAMSUNG Galaxy F04 (Jade Purple, 64 GB)      4.2   ₹6,999
# 7         SAMSUNG Galaxy F04 (Opal Green, 64 GB)      4.2   ₹6,999
# 8     SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)      4.2  ₹13,990
# 9   SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)      4.3  ₹15,499
# 10     SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)      4.2  ₹13,990
# 11         SAMSUNG Galaxy M04 (Dark Blue, 64 GB)      4.1   ₹8,093
# 12    SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)      4.3   ₹9,499
# 13       SAMSUNG Galaxy M04 (Light Green, 64 GB)      4.1   ₹8,185
# ...

# %%
df[['name','ratings']].head(5)
# Out:
#                                           name  ratings
# 0   SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3
# 1  SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3
# 2  SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3
# 3  SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      4.3
# 4    SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3

# %%
df.describe()
# Out:
#           ratings
# count  553.000000
# mean     4.197468
# std      0.203931
# min      2.900000
# 25%      4.100000
# 50%      4.200000
# 75%      4.300000
# max      4.800000
