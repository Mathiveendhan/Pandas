# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Admin\OneDrive\Documents\Dataset\samsung_mobile_new_data.csv")
df
# Out:
#                                                 name  ratings    price  \
# 0         SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3   ₹9,499
# 1        SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  ₹10,499
# 2        SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3  ₹10,499
# 3        SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      4.3  ₹10,499
# 4          SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3  ₹15,499
# ..                                               ...      ...      ...
# 571  SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)      4.3  ₹16,199
# 572            SAMSUNG Galaxy J4 Plus (Black, 32 GB)      4.4   ₹9,000
# 573   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)      4.2  ₹34,999
# 574                SAMSUNG Galaxy M01s (Gray, 32 GB)      NaN  ₹10,999
# 575           SAMSUNG Galaxy S22 (Pink Gold, 128 GB)      NaN  ₹85,999
#
#                                                 imgURL  \
# 0    https://rukminim2.flixcart.com/image/312/312/x...
# ...

# %%
df['combine']=df['name']+' '+df['price']

# %%
df['combine']
# Out:
# 0      SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB) ₹9,499
# 1      SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB) ₹1...
# 2      SAMSUNG Galaxy F13 (Nightsky Green, 128 GB) ₹1...
# 3      SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB) ₹1...
# 4      SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB) ₹15,499
#                              ...
# 571    SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB...
# 572         SAMSUNG Galaxy J4 Plus (Black, 32 GB) ₹9,000
# 573    SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)...
# 574            SAMSUNG Galaxy M01s (Gray, 32 GB) ₹10,999
# 575       SAMSUNG Galaxy S22 (Pink Gold, 128 GB) ₹85,999
# Name: combine, Length: 576, dtype: object

# %%
df.head(2)
# Out:
#                                           name  ratings    price  \
# 0   SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3   ₹9,499
# 1  SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  ₹10,499
#
#                                               imgURL  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...
# 1  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                          storage_ram  \
# 0  Internal Storage64 GBRAM4 GBExpandable Storage...
# 1  Internal Storage128 GBRAM4 GBExpandable Storag...
#
#                                         os_processor  \
# 0  Operating SystemAndroid 12Processor TypeExynos...
# 1  Operating SystemAndroid 12Processor TypeExynos...
#
#                                               camera  \
# 0  Primary Camera AvailableYesPrimary Camera50MP ...
# 1  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                              display  \
# 0  Display Size16.76 cm (6.6 inch)Resolution2408 ...
# ...

# %%
################################## remove column #######################################

# %%
df.drop(columns=['combine'])
# Out:
#                                                 name  ratings    price  \
# 0         SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3   ₹9,499
# 1        SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  ₹10,499
# 2        SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3  ₹10,499
# 3        SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      4.3  ₹10,499
# 4          SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3  ₹15,499
# ..                                               ...      ...      ...
# 571  SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)      4.3  ₹16,199
# 572            SAMSUNG Galaxy J4 Plus (Black, 32 GB)      4.4   ₹9,000
# 573   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)      4.2  ₹34,999
# 574                SAMSUNG Galaxy M01s (Gray, 32 GB)      NaN  ₹10,999
# 575           SAMSUNG Galaxy S22 (Pink Gold, 128 GB)      NaN  ₹85,999
#
#                                                 imgURL  \
# 0    https://rukminim2.flixcart.com/image/312/312/x...
# ...

# %%
df['network']=df['network'].str.replace(',','')

# %%
df['network'].str.split()
# Out:
# 0      [Network, Type4G, 3G, 2GSupported, Networks4G,...
# 1      [Network, Type4G, 3G, 2GSupported, Networks4G,...
# 2      [Network, Type4G, 3G, 2GSupported, Networks4G,...
# 3      [Network, Type4G, 3G, 2GSupported, Networks4G,...
# 4      [Network, Type5G, 4G, 3G, 2GSupported, Network...
#                              ...
# 571    [Network, Type3G, 4G, 2GSupported, NetworksGSM...
# 572    [Network, Type3G, 4G, 2GSupported, NetworksGSM...
# 573    [Network, Type4G, VOLTE, 4G, 3G, 2GSupported, ...
# 574    [Network, Type4G, VOLTE, 3GSupported, Networks...
# 575               [Network, Type5GSupported, Networks5G]
# Name: network, Length: 576, dtype: object

# %%
df['network'].str.split(expand=True)
# Out:
#           0                1           2            3            4   \
# 0    Network           Type4G          3G  2GSupported   Networks4G
# 1    Network           Type4G          3G  2GSupported   Networks4G
# 2    Network           Type4G          3G  2GSupported   Networks4G
# 3    Network           Type4G          3G  2GSupported   Networks4G
# 4    Network           Type5G          4G           3G  2GSupported
# ..       ...              ...         ...          ...          ...
# 571  Network           Type3G          4G  2GSupported  NetworksGSM
# 572  Network           Type3G          4G  2GSupported  NetworksGSM
# 573  Network           Type4G       VOLTE           4G           3G
# 574  Network           Type4G       VOLTE  3GSupported   Networks4G
# 575  Network  Type5GSupported  Networks5G         None         None
#
#               5            6               7               8            9   \
# ...

# %%
person={
    "name":["SAMSUNG Galaxy F13","SAMSUNG Galaxy F14 5G","SAMSUNG Galaxy M33 5G","SAMSUNG Galaxy A34 5G"],
    "ratings":["4.3","4.2","4.3","4.1"],
    "camera":["Camera50MP","Camera60MP","Camera80MP","Camera40MP"],
    "network":["Network Type4G, 3G, 2G","Network Type4G, 3G, 2G","Network Type2G","Network Type4G"]
} 
df2=pd.DataFrame(person)

# %%
df2
# Out:
#                     name ratings      camera                 network
# 0     SAMSUNG Galaxy F13     4.3  Camera50MP  Network Type4G, 3G, 2G
# 1  SAMSUNG Galaxy F14 5G     4.2  Camera60MP  Network Type4G, 3G, 2G
# 2  SAMSUNG Galaxy M33 5G     4.3  Camera80MP          Network Type2G
# 3  SAMSUNG Galaxy A34 5G     4.1  Camera40MP          Network Type4G

# %%
#df.append(df2)                ########### error ####################
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2600\2094904254.py in ?()
# ----> 1 df.append(df2)
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df.drop(index=1)
# Out:
#                                                 name  ratings    price  \
# 0         SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3   ₹9,499
# 2        SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3  ₹10,499
# 3        SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      4.3  ₹10,499
# 4          SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3  ₹15,499
# 5       SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)      4.3  ₹15,499
# ..                                               ...      ...      ...
# 571  SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)      4.3  ₹16,199
# 572            SAMSUNG Galaxy J4 Plus (Black, 32 GB)      4.4   ₹9,000
# 573   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)      4.2  ₹34,999
# 574                SAMSUNG Galaxy M01s (Gray, 32 GB)      NaN  ₹10,999
# 575           SAMSUNG Galaxy S22 (Pink Gold, 128 GB)      NaN  ₹85,999
#
#                                                 imgURL  \
# 0    https://rukminim2.flixcart.com/image/312/312/x...
# ...

# %%
df.head(2)
# Out:
#                                           name  ratings    price  \
# 0   SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3   ₹9,499
# 1  SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  ₹10,499
#
#                                               imgURL  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...
# 1  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                          storage_ram  \
# 0  Internal Storage64 GBRAM4 GBExpandable Storage...
# 1  Internal Storage128 GBRAM4 GBExpandable Storag...
#
#                                         os_processor  \
# 0  Operating SystemAndroid 12Processor TypeExynos...
# 1  Operating SystemAndroid 12Processor TypeExynos...
#
#                                               camera  \
# 0  Primary Camera AvailableYesPrimary Camera50MP ...
# 1  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                              display  \
# 0  Display Size16.76 cm (6.6 inch)Resolution2408 ...
# ...

# %%
filt= df['price']=='₹9,499'
df.drop(index=df[filt].index)
# Out:
#                                                 name  ratings    price  \
# 1        SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  ₹10,499
# 2        SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3  ₹10,499
# 3        SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      4.3  ₹10,499
# 4          SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3  ₹15,499
# 5       SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)      4.3  ₹15,499
# ..                                               ...      ...      ...
# 571  SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)      4.3  ₹16,199
# 572            SAMSUNG Galaxy J4 Plus (Black, 32 GB)      4.4   ₹9,000
# 573   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)      4.2  ₹34,999
# 574                SAMSUNG Galaxy M01s (Gray, 32 GB)      NaN  ₹10,999
# 575           SAMSUNG Galaxy S22 (Pink Gold, 128 GB)      NaN  ₹85,999
#
#                                                 imgURL  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# ...
