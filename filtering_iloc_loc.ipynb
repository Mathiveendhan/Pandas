# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Admin\OneDrive\Documents\Dataset\samsung_mobile_new_data.csv")
df
# Out:
#                                                 name  ratings    price  \
# 0         SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3   ₹9,499
# 1        SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  ₹10,499
# 2        SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3  ₹10,499
# 3        SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      4.3  ₹10,499
# 4          SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3  ₹15,499
# ..                                               ...      ...      ...
# 571  SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)      4.3  ₹16,199
# 572            SAMSUNG Galaxy J4 Plus (Black, 32 GB)      4.4   ₹9,000
# 573   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)      4.2  ₹34,999
# 574                SAMSUNG Galaxy M01s (Gray, 32 GB)      NaN  ₹10,999
# 575           SAMSUNG Galaxy S22 (Pink Gold, 128 GB)      NaN  ₹85,999
#
#                                                 imgURL  \
# 0    https://rukminim2.flixcart.com/image/312/312/x...
# ...

# %%
# df["price"]=="₹9,000"
filt=df["price"]=="₹9,000"

# %%
df.loc[filt,'name']                                      #########################
# Out:
# 572    SAMSUNG Galaxy J4 Plus (Black, 32 GB)
# Name: name, dtype: object

# %%
### AND  OR #####

# %%
flit1=(df["price"]=="₹15,499") | (df["ratings"]=="4.3")

# %%
df.loc[flit1]
# Out:
#                                              name  ratings    price  \
# 4       SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3  ₹15,499
# 5    SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)      4.3  ₹15,499
# 9    SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)      4.3  ₹15,499
# 151             SAMSUNG Galaxy M12 (Blue, 128 GB)      4.3  ₹15,499
# 209             SAMSUNG Galaxy M12 (Blue, 128 GB)      4.2  ₹15,499
# 229            SAMSUNG Galaxy A14 (Black, 128 GB)      3.9  ₹15,499
# 230      SAMSUNG Galaxy A14 (Light Green, 128 GB)      3.9  ₹15,499
# 264             SAMSUNG Galaxy A13 (Blue, 128 GB)      4.1  ₹15,499
#
#                                                 imgURL  \
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# 5    https://rukminim2.flixcart.com/image/312/312/x...
# 9    https://rukminim2.flixcart.com/image/312/312/x...
# 151  https://rukminim2.flixcart.com/image/312/312/k...
# 209  https://rukminim2.flixcart.com/image/312/312/k...
# ...

# %%
flit1=(df["price"]=="₹15,499") | (df["ratings"]=="4.3")
df.loc[flit1,'name']
# Out:
# 4         SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)
# 5      SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)
# 9      SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)
# 151               SAMSUNG Galaxy M12 (Blue, 128 GB)
# 209               SAMSUNG Galaxy M12 (Blue, 128 GB)
# 229              SAMSUNG Galaxy A14 (Black, 128 GB)
# 230        SAMSUNG Galaxy A14 (Light Green, 128 GB)
# 264               SAMSUNG Galaxy A13 (Blue, 128 GB)
# Name: name, dtype: object

# %%
df.columns
# Out:
# Index(['name', 'ratings', 'price', 'imgURL', 'storage_ram', 'os_processor',
#        'camera', 'display', 'network', 'battery'],
#       dtype='object')

# %%
df.loc[(df["price"]>'₹9,000'),["storage_ram","battery","network"]]
# Out:
#                                            storage_ram  \
# 0    Internal Storage64 GBRAM4 GBExpandable Storage...
# 12   Internal Storage64 GBRAM4 GBExpandable Storage...
# 17   Internal Storage64 GBRAM4 GBExpandable Storage...
# 20                       Internal Storage128 GBRAM4 GB
# 73   Internal Storage64 GBRAM3 GBTotal Memory64 GBE...
# 77     Internal Storage256 GBRAM8 GBTotal Memory256 GB
# 100                      Internal Storage256 GBRAM8 GB
# 101  Internal Storage32 GBRAM3 GBSupported Memory C...
# 139  Internal Storage32 GBRAM3 GBSupported Memory C...
# 143  Internal Storage64 GBRAM3 GBTotal Memory64 GBE...
# 165  Internal Storage64 GBRAM3 GBMemory Card Slot T...
# 166  Internal Storage32 GBRAM3 GBSupported Memory C...
# 188                      Internal Storage256 GBRAM8 GB
# 222  Internal Storage64 GBRAM4 GBTotal Memory64 GBE...
# 233  Internal Storage64 GBRAM4 GBTotal Memory64 GBE...
# 268                     Internal Storage256 GBRAM12 GB
# ...

# %%
df.loc[(df["price"]>'₹15,499'),['name',"os_processor"]]
# Out:
#                                                 name  \
# 0         SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)
# 6            SAMSUNG Galaxy F04 (Jade Purple, 64 GB)
# 7             SAMSUNG Galaxy F04 (Opal Green, 64 GB)
# 11             SAMSUNG Galaxy M04 (Dark Blue, 64 GB)
# 12        SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)
# ..                                               ...
# 569       SAMSUNG Galaxy M40 (Seawater Blue, 128 GB)
# 571  SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)
# 572            SAMSUNG Galaxy J4 Plus (Black, 32 GB)
# 573   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)
# 575           SAMSUNG Galaxy S22 (Pink Gold, 128 GB)
#
#                                           os_processor
# 0    Operating SystemAndroid 12Processor TypeExynos...
# 6    Operating SystemAndroid 12Processor TypeMediat...
# 7    Operating SystemAndroid 12Processor TypeMediat...
# 11   Operating SystemAndroid 12Processor TypeMediaT...
# ...

# %%
flit2 = df["os_processor"].str.contains('12Processor')     ##################### contains

# %%
#df.loc[flit2]
flit3
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 571    False
# 572    False
# 573    False
# 574    False
# 575    False
# Name: storage_ram, Length: 576, dtype: object

# %%
flit3 = df["storage_ram"].str.contains('Storage128 GBRAM4')

# %%
flit3
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 571    False
# 572    False
# 573    False
# 574    False
# 575    False
# Name: storage_ram, Length: 576, dtype: object
