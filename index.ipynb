# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Admin\OneDrive\Documents\Dataset\samsung_mobile_new_data.csv")
df
# Out:
#                                                 name  ratings    price  \
# 0         SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3   ₹9,499
# 1        SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  ₹10,499
# 2        SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3  ₹10,499
# 3        SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      4.3  ₹10,499
# 4          SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3  ₹15,499
# ..                                               ...      ...      ...
# 571  SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)      4.3  ₹16,199
# 572            SAMSUNG Galaxy J4 Plus (Black, 32 GB)      4.4   ₹9,000
# 573   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)      4.2  ₹34,999
# 574                SAMSUNG Galaxy M01s (Gray, 32 GB)      NaN  ₹10,999
# 575           SAMSUNG Galaxy S22 (Pink Gold, 128 GB)      NaN  ₹85,999
#
#                                                 imgURL  \
# 0    https://rukminim2.flixcart.com/image/312/312/x...
# ...

# %%
df["name"]
# Out:
# 0           SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)
# 1          SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)
# 2          SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)
# 3          SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)
# 4            SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)
#                             ...
# 571    SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)
# 572              SAMSUNG Galaxy J4 Plus (Black, 32 GB)
# 573     SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)
# 574                  SAMSUNG Galaxy M01s (Gray, 32 GB)
# 575             SAMSUNG Galaxy S22 (Pink Gold, 128 GB)
# Name: name, Length: 576, dtype: object

# %%
df.set_index('name')
# Out:
#                                                  ratings    price  \
# name
# SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)           4.3   ₹9,499
# SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)          4.3  ₹10,499
# SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)          4.3  ₹10,499
# SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)          4.3  ₹10,499
# SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)            4.3  ₹15,499
# ...                                                  ...      ...
# SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)      4.3  ₹16,199
# SAMSUNG Galaxy J4 Plus (Black, 32 GB)                4.4   ₹9,000
# SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)       4.2  ₹34,999
# SAMSUNG Galaxy M01s (Gray, 32 GB)                    NaN  ₹10,999
# SAMSUNG Galaxy S22 (Pink Gold, 128 GB)               NaN  ₹85,999
#
#                                                                                             imgURL  \
# name
# ...

# %%
df=df.set_index('name')

# %%
df.loc["SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)",'price']
# Out:
# '₹9,499'

# %%
df.loc["SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)":"SAMSUNG Galaxy S22 (Pink Gold, 128 GB)"  ,  'price':'network']
# Out:
#                                                    price  \
# name
# SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)        ₹9,499
# SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      ₹10,499
# SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      ₹10,499
# SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      ₹10,499
# SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)        ₹15,499
# ...                                                  ...
# SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)  ₹16,199
# SAMSUNG Galaxy J4 Plus (Black, 32 GB)             ₹9,000
# SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)   ₹34,999
# SAMSUNG Galaxy M01s (Gray, 32 GB)                ₹10,999
# SAMSUNG Galaxy S22 (Pink Gold, 128 GB)           ₹85,999
#
#                                                                                             imgURL  \
# name
# SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)       https://rukminim2.flixcart.com/image/312/312/x...
# ...

# %%
df.loc["SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)"]
# Out:
# ratings                                                       4.3
# price                                                      ₹9,499
# imgURL          https://rukminim2.flixcart.com/image/312/312/x...
# storage_ram     Internal Storage64 GBRAM4 GBExpandable Storage...
# os_processor    Operating SystemAndroid 12Processor TypeExynos...
# camera          Primary Camera AvailableYesPrimary Camera50MP ...
# display         Display Size16.76 cm (6.6 inch)Resolution2408 ...
# network         Network Type4G, 3G, 2GSupported Networks4G LTE...
# battery                    Battery Capacity6000 mAhDual BatteryNo
# Name: SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB), dtype: object

# %%
#####reset the dataframe ####

# %%
df.reset_index()
# Out:
#                                                 name  ratings    price  \
# 0         SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3   ₹9,499
# 1        SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  ₹10,499
# 2        SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3  ₹10,499
# 3        SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      4.3  ₹10,499
# 4          SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3  ₹15,499
# ..                                               ...      ...      ...
# 571  SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)      4.3  ₹16,199
# 572            SAMSUNG Galaxy J4 Plus (Black, 32 GB)      4.4   ₹9,000
# 573   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)      4.2  ₹34,999
# 574                SAMSUNG Galaxy M01s (Gray, 32 GB)      NaN  ₹10,999
# 575           SAMSUNG Galaxy S22 (Pink Gold, 128 GB)      NaN  ₹85,999
#
#                                                 imgURL  \
# 0    https://rukminim2.flixcart.com/image/312/312/x...
# ...

# %%
######################################################################################################################

# %%
import pandas as pd
df1=pd.read_csv(r"C:\Users\Admin\OneDrive\Documents\Dataset\samsung_mobile_new_data.csv",index_col='name')
df1
# Out:
#                                                  ratings    price  \
# name
# SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)           4.3   ₹9,499
# SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)          4.3  ₹10,499
# SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)          4.3  ₹10,499
# SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)          4.3  ₹10,499
# SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)            4.3  ₹15,499
# ...                                                  ...      ...
# SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)      4.3  ₹16,199
# SAMSUNG Galaxy J4 Plus (Black, 32 GB)                4.4   ₹9,000
# SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)       4.2  ₹34,999
# SAMSUNG Galaxy M01s (Gray, 32 GB)                    NaN  ₹10,999
# SAMSUNG Galaxy S22 (Pink Gold, 128 GB)               NaN  ₹85,999
#
#                                                                                             imgURL  \
# name
# ...
